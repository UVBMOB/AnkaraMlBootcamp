# %%
from Odevler.odev1.Odev1Class import DataClass
dataclass=DataClass()#orneklem
dataclass.ortalama()
# Out:
# orneklem: [66 40 98 74 17 80 34 26 75 77 88 78 26 16  6]
# orneklem ortalama: 53.4

# %%
dataclass.pdf_ciz()

# %%
dataclass.cdf_ciz()

# %%
dataclass.cizgi_grafigi_ciz()

# %%
dataclass.dagilim_grafigi_ciz()

# %%
dataclass.histogram_ciz()
